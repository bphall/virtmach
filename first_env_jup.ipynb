# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-544d7160a08f> in <module>
#      10 from sklearn.ensemble import RandomForestRegressor
#      11 from sklearn.model_selection import GridSearchCV
# ---> 12 import xgboost as xgb
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
string = 'abc'
for i in string:
    print(i)
# Out:
# a
# b
# c

# %%
y = string.count('a')

# %%
y
# Out:
# 1

# %%
pip install xgboost
# Out:
# ...
#   Using cached xgboost-1.0.2.tar.gz (821 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/braytonhall/first_venv/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-pzpl9o_z/xgboost/setup.py'"'"'; __file__='"'"'/private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-pzpl9o_z/xgboost/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-pip-egg-info-m1gpi7zm
#          cwd: /private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-pzpl9o_z/xgboost/
#     Complete output (27 lines):
#     ++ pwd
#     + oldpath=/private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-pzpl9o_z/xgboost
#     + cd ./xgboost/
#     + mkdir -p build
# ...

# %%
pip install xgboost
# Out:
# ...
#   Using cached xgboost-1.0.2.tar.gz (821 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/braytonhall/first_venv/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-4xnksmmf/xgboost/setup.py'"'"'; __file__='"'"'/private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-4xnksmmf/xgboost/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-pip-egg-info-_8mxhyn5
#          cwd: /private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-4xnksmmf/xgboost/
#     Complete output (27 lines):
#     ++ pwd
#     + oldpath=/private/var/folders/2y/16m4s7qd2y9d7bbqrjdjjdpr0000gn/T/pip-install-4xnksmmf/xgboost
#     + cd ./xgboost/
#     + mkdir -p build
# ...

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
non_price = df.drop(['price', 'date'], axis=1)

# %%
target = df.price

# %%
sqft_grade = df[['sqft_living', 'grade']]

# %%
X_train, X_test, y_train, y_test = train_test_split(non_price, target, test_size=0.3, random_state = 42)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
rf = RandomForestRegressor(n_estimators = 50, max_depth=20, random_state=42)

# %%
param_grid = dict(n_estimators=[10, 25, 50, 100, 500],
                  max_depth=[5, 10, 20, 30],
                  min_samples_leaf=[1,2,4])

# %%
grid = GridSearchCV(rf, param_grid, cv=10,
                    scoring='neg_mean_squared_error', verbose=2, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 60 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed: 20.9min finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=6,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
# ...

# %%
grid.best_params_
# Out:
# {'max_depth': 20, 'min_samples_leaf': 1, 'n_estimators': 50}

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=20, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 300, 'max_features': 'auto', 'max_depth': 6}

# %%
preds = lr.predict(X_test)

# %%
predsrf = rf.predict(X_test)

# %%
mean_squared_error(preds, y_test)**.5
# Out:
# 208251.69992725694

# %%
mean_squared_error(predsrf, y_test)**.5
# Out:
# 145009.03812978702

# %%
basepreds = [y_train.mean() for i in y_test]

# %%
mean_squared_error(basepreds, y_test)**.5
# Out:
# 380043.56780973694

# %%
# Out:
# 15129

# %%
sns.heatmap(df.corr())

# %%
X_train
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 167    1836980160         4       2.50         2680      4499     2.0
# 12412  9221400335         4       1.75         2340      5080     1.0
# 7691   6669020490         4       2.25         2190      9020     2.0
# 12460  2025079045         2       1.75         2260    280962     2.0
# 9099   1525069058         4       1.75         2110    265716     1.0
# ...           ...       ...        ...          ...       ...     ...
# 11964  5272200045         3       1.50         1000      6914     1.0
# 21575  9578500790         3       2.50         3087      5002     2.0
# 5390   7202350480         3       2.50         2120      4780     2.0
# 860    1723049033         1       0.75          380     15000     1.0
# 15795  6147650280         4       2.50         3130      5999     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
X_test
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 735    2591820310         4       2.25         2070      8893     2.0
# 2830   7974200820         5       3.00         2900      6730     1.0
# 4106   7701450110         4       2.50         3770     10893     2.0
# 16218  9522300010         3       3.50         4560     14608     2.0
# 19964  9510861140         3       2.50         2550      5376     2.0
# ...           ...       ...        ...          ...       ...     ...
# 12606  1402660150         3       2.50         2210      7000     2.0
# 14393  2301400325         3       2.00         1810      4500     1.0
# 6899   6150200005         3       1.00         1150      6800     1.0
# 85     4232902595         3       1.50         2140      3600     2.0
# 21363  3782760080         4       2.25         2510      4090     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
sns.heatmap(df.isna(), cbar=False)

# %%
df.lat.describe()
# Out:
# count    21613.000000
# mean        47.560053
# std          0.138564
# min         47.155900
# 25%         47.471000
# 50%         47.571800
# 75%         47.678000
# max         47.777600
# Name: lat, dtype: float64

# %%
sns.lmplot('lat', 'long', data=df, hue='view')
